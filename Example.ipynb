# %%
from utils.Segmentation_Function import image_segmentation
from utils.Icon_Creator_Function import create_icons
from utils.Layout_Function import create_text_images

from utils.full_pipeline import generate_icons, generate_text_image, display_generated_images

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Example 1: Bus

# %% [markdown]
# #### Step by Step

# %%
img_path_seg = "01_Input_Images/bus.jpg"
save_path_seg = "02_Segmentation_Images"

image_segmentation(image_path=img_path_seg, save_path=save_path_seg)
# Out:
# [Image Segmentation]: Running
# [Image Segmentation]: Finished

# %%
model_dir = "checkpoints/Objects2Icons/"
img_input_dir = "02_Segmentation_Images/bus"
img_output_dir = "03_Output_Images"

create_icons(model_dir, img_input_dir, img_output_dir)
# Out:
# [Image2Icon]: Running
# [Image2Icon]: Finished
# [PNG2SVG]: Running
# [PNG2SVG]: Finished

# %%
img_path_layout = "03_Output_Images/bus/Objects2Icons/test_70/images/bus_Instance_Segmentation_1_fake.png"
save_path_layout = "03_Output_Images/bus/Text Images"

image_list_bus = create_text_images(img_path_layout, save_path_layout, "00_Fonts/42.ttf", "Bus Company")
display_generated_images(image_list_bus)
# Out:
# [Layout]: Running
# [Layout]: Finished

# %% [markdown]
# #### Shortened

# %%
generate_icons(img_path_seg)
image_list_bus = generate_text_image(img_path_layout, "00_Fonts/42.ttf", "Bus Company")
display_generated_images(image_list_bus)
# Out:
# [Image Segmentation]: Running
# [Image Segmentation]: Finished
# [Image2Icon]: Running
# [Image2Icon]: Finished
# [PNG2SVG]: Running
# [PNG2SVG]: Finished
# [Layout]: Running
# [Layout]: Finished

# %% [markdown]
# # Example 2: Snowboarder

# %% [markdown]
# #### Step by Step

# %%
image_path_seg = "01_Input_Images/snowboarder.jpg"
save_path_seg = "02_Segmentation_Images"

image_segmentation(image_path=image_path_seg, save_path=save_path_seg)
# Out:
# [Image Segmentation]: Running
# [Image Segmentation]: Finished

# %%
model_dir = "checkpoints/Objects2Icons/"
img_input_dir = "02_Segmentation_Images/snowboarder"
img_output_dir = "03_Output_Images"

create_icons(model_dir, img_input_dir, img_output_dir)
# Out:
# [Image2Icon]: Running
# [Image2Icon]: Finished
# [PNG2SVG]: Running
# [PNG2SVG]: Finished

# %%
img_path_layout = "03_Output_Images/snowboarder/Objects2Icons/test_90/images/snowboarder_Region_Segmentation_1_fake.png"
save_path_layout = "03_Output_Images/snowboarder/Text Images"

image_list_snowboarder = create_text_images(img_path_layout, save_path_layout, "00_Fonts/Classic Rock.ttf", "Snowboarding")
display_generated_images(image_list_snowboarder)
# Out:
# [Layout]: Running
# [Layout]: Finished

# %% [markdown]
# #### Shortened

# %%
generate_icons(img_path_seg)
image_list_snowboarder = generate_text_image(img_path_layout,  "00_Fonts/Classic Rock.ttf", "Snowboarding")
display_generated_images(image_list_snowboarder)
# Out:
# [Image Segmentation]: Running
# [Image Segmentation]: Finished
# [Image2Icon]: Running
# [Image2Icon]: Finished
# [PNG2SVG]: Running
# [PNG2SVG]: Finished
# [Layout]: Running
# [Layout]: Finished
